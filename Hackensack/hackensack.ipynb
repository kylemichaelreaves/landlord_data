# %% [markdown]
# ### import dataframes whether initially as csv or subsequently as a pickle

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
geolocator = Nominatim(user_agent="myGeolocator", timeout=2)

def getPropertiesOwned(owner=str):
    return df[df.ownersName == owner]['propertyLocation'].unique().tolist()

# number of times property appears in first column
def getUnits(address=str):
    return len(df[df.propertyLocation == address])

# number of the properties owned by the given owner
def getNumberOwned(owner=str):
    return df[(df.ownersName == owner)]['propertyLocation'].count()

df = pd.read_pickle('hackensack.pkl')
errors_df = pd.read_pickle('errors_df.pkl')

# df = pd.read_csv('/Users/kylereaves/Desktop/landlord_data/Hackensack/0223msnj003247.csv', 
# usecols=["Property Location", "Owner's Name", "Owner's Mailing Address", "City/State/Zip"])

# df.rename(columns={'Property Location': 'propertyLocation',
#                      "Owner's Name": "ownersName",
#                      "Owner's Mailing Address": "ownersMailingAddress",
#                      "City/State/Zip": "cityStateZip"}, inplace=True)

# %%
# df['units'] = [getUnits(address) for address in df.propertyLocation]
# df['propertiesOwned'] = [getPropertiesOwned(owner) for owner in df.ownersName]
# df['getNumberPropertiesOwned'] = [getNumberOwned(owner) for owner in df.ownersName]

# %%
df
# Out:
#      propertyLocation                           ownersName  \
# 0     25 MOONACHIE RD         TOWER ARCADIA COURT 2015 LLC
# 1      511 HUDSON ST.              REYES,JUAN C & HERMINIA
# 2       606 HUDSON ST    DURANTE, MICHAEL D & CARMENCITA Y
# 3       598 HUDSON ST  594 HUDSON STREET REALTY ASSOCIATES
# 4       608 HUDSON ST        O'CONNELL, MICHAEL & CATHLEEN
# ...               ...                                  ...
# 8227     33 S LAKE DR          WICKERSHEIM, ROBERT & CAROL
# 8228     31 S LAKE DR                        PEREZ,ADRIANA
# 8229     29 S LAKE DR      SILVESTRI, ANGELO J. & MADELINE
# 8230     27 S LAKE DR       RHODEN,SHEAN & SANCHEZ,SOLANYI
# 8231     21 S LAKE DR                     THORNTON, BONITA
#
#      ownersMailingAddress           cityStateZip  units    propertiesOwned  \
# 0     680 KINDERKAMACK RD  RIVER EDGE, NJ  07661      1  [25 MOONACHIE RD]
# 1           511 HUDSON ST  HACKENSACK, NJ  07601      1   [511 HUDSON ST.]
# 2           606 HUDSON ST  HACKENSACK, NJ  07601      1    [606 HUDSON ST]
# 3       598 HUDSON STREET  HACKENSACK, NJ  07601      1    [598 HUDSON ST]
# 4        62 GREENBRIAR RD     PARAMUS, NJ  07652      1    [608 HUDSON ST]
# ...                   ...                    ...    ...                ...
# 8227        126 CEDAR AVE   HACKENSACK NJ  07601      1    [33 SO LAKE DR]
# 8228        31 SO LAKE DR  HACKENSACK, NJ  07601      1    [31 SO LAKE DR]
# 8229         29 S LAKE DR   HACKENSACK NJ  07601      1    [29 SO LAKE DR]
# 8230         27 S LAKE DR  HACKENSACK, NJ  07601      1    [27 SO LAKE DR]
# 8231         21 S LAKE DR  HACKENSACK, NJ  07601      1    [21 SO LAKE DR]
#
#       getNumberPropertiesOwned              propertyFullAddress  \
# 0                            1  25 MOONACHIE RD, HACKENSACK, NJ
# 1                            1   511 HUDSON ST., HACKENSACK, NJ
# 2                            1    606 HUDSON ST, HACKENSACK, NJ
# 3                            1    598 HUDSON ST, HACKENSACK, NJ
# 4                            1    608 HUDSON ST, HACKENSACK, NJ
# ...                        ...                              ...
# 8227                         1     33 S LAKE DR, HACKENSACK, NJ
# 8228                         1     31 S LAKE DR, HACKENSACK, NJ
# 8229                         1     29 S LAKE DR, HACKENSACK, NJ
# 8230                         1     27 S LAKE DR, HACKENSACK, NJ
# 8231                         1     21 S LAKE DR, HACKENSACK, NJ
#
#                                                   gCode        Lat       Long
# 0     (25, Moonachie Road, Hackensack, Bergen County...  40.861991 -74.039175
# 1     (511, Hudson Street, Hackensack, Bergen County...  40.862308 -74.037843
# 2     (606, Hudson Street, Hackensack, Bergen County...  40.860612 -74.036937
# 3     (598, Hudson Street, Hackensack, Bergen County...  40.860758 -74.036995
# 4     (608, Hudson Street, Hackensack, Bergen County...  40.860576 -74.036923
# ...                                                 ...        ...        ...
# 8227  (33, South Lake Drive, North Hackensack, Hacke...        NaN        NaN
# 8228  (31, South Lake Drive, North Hackensack, Hacke...        NaN        NaN
# 8229  (29, South Lake Drive, North Hackensack, Hacke...        NaN        NaN
# 8230  (27, South Lake Drive, North Hackensack, Hacke...        NaN        NaN
# 8231  (21, South Lake Drive, North Hackensack, Hacke...        NaN        NaN
#
# [8206 rows x 11 columns]

# %% [markdown]
# ## add lat and long for coordinates which geocoded last call

# %%
df['Lat'] = [g.latitude for g in df.gCode]
df['Long'] = [g.longitude for g in df.gCode]

df.to_pickle('hackensack.pkl')

# %%
errors_df
# Out:
#                propertyLocation                           ownersName  \
# 282    387A & 387B WILLIAMS AVE     TORNAMBE, SALVATORE G & PAOLO JR
# 500            182 BONHOMME AVE                     TENEZACA, MANUEL
# 702     45 JACKSON AVE, UNIT #1                     JACKSON PINK LLC
# 703     45 JACKSON AVE, UNIT #2                     JACKSON PINK LLC
# 733             10 VAN WETERING  PEREZ,JAIME & TERESA C/O ALBA PEREZ
# 735            115 SO RIVER ST.    CHESSARI, FRANK & MARY ( TRUSTEE)
# 736          36 VAN WETERING PL                     PUNTASECCA, RORY
# 862        101 KANSAS &46 STATE                  SIGUENCIA, TRANSITO
# 952   163 KANSAS ST & 47 HOBART       SOLIS,GILMO F & TORNO,BERNARDO
# 957                74 MC KINLEY                  TAMAY, LUIS & MARIA
# 1053            222 ELLEEN TERR        222 ELLEEN TERRACE, LLC %MELI
# 1163     360 W PLEASANTVIEW AVE    ROYAL TOWERS ASSOC % SALEM MTG CO
# 1422       MARVIN & PROSPECT AV                  CASAMENTI, ALPHONSO
# 2255             170 SO PARK ST                HACKENSACK NORSE, LLC
# 2272             189 SO PARK ST    BACOTE,JANICE & RICHARDSON,CHANDA
# 2273             187 SO PARK ST         BERGEN REALTY MANAGEMENT LLC
# 2274          183-85 SO PARK ST           CAMPOVERDE, EDISON & ANA P
# 2275             179 SO PARK ST    VELAZQUEZ,JESUS & MARGARET & MARY
# 2276             177 SO PARK ST  DEWINDT,DODLEY R &LYNETH E ANDERSON
# 2292             202 RUSSEL PL.          MORQUECHO, GABRIEL & GLORIA
# 2328        90 PROSPECT AVE #4F    COOPER,JAMES C. & CUONO, LORRAINE
# 2943  280-84 AMERICAN LEGION DR           FRANCISCO APARTMENTS, INC.
# 2965         365 AMER LEGION DR                     GANZ, JOEL TRSTE
# 3001         ESSEX & ARCADIA RD              SDK SUMMIT GARDENS, LLC
# 3002           95-167 TRACY PL.     GLEN VIEW ASSOC. C/O HANSON MGMT
# 3026   5-65 ARCADIA & 450 ESSEX             TULANE HOLDINGS LLC ETAL
# 3069         161-1631/2 MAIN ST           MAIN STREET HACKENSACK LLC
# 3077          1 & 2 PARK AVENUE    R&H HACKENSACK URBAN RENEWAL, LLC
# 3388        295-97 RAILROAD AVE                        PERSON, GARRY
# 3492          215-17-21 2ND ST.          FAO GARDENS ASSOCIATES, LLC
# 5978          321 SO EUCLID AVE           TROIANO, MICHAEL & VALERIE
# 5981          333 SO EUCLID AVE                    RICHMOND, MAUREEN
# 6122          448-50 W ANDERSON                    JMRC HOLDING, LLC
# 6419   140 GRAND & 50 FAIRMOUNT              FERRARO PROPERTIES, LLC
# 7446           889-895 MAIN ST.                A & K ASSOCIATES, LLC
# 7617            256-58 LOUIS ST                    LEWIS, MARGARET O
# 7869          256-58 LINCOLN ST                LUPPINO, LOUIS & ANNA
#
#            ownersMailingAddress                 cityStateZip  units  \
# 282              410 TAYLOR AVE        HACKENSACK, NJ  07601      1
# 500             182 BONHOMME ST        HACKENSACK, NJ  07601      1
# 702      224 LINDA VISTA AVENUE     NORTH HALEDON, NJ  07508      1
# 703      224 LINDA VISTA AVENUE     NORTH HALEDON, NJ  07508      1
# 733           248 MARVIN AVENUE         HACKENSACK NJ  07601      1
# 735           248 PHILLIPS AVE.   SOUTH HACKENSACK NJ  07606      1
# 736          36 VAN WETERING PL        HACKENSACK, NJ  07601      1
# 862               101 KANSAS ST        HACKENSACK, NJ  07601      1
# 952               163 KANSAS ST        HACKENSACK, NJ  07601      1
# 957                 108 FAIR ST        HACKENSACK, NJ  07601      1
# 1053                 PO BOX 100        HACKENSACK, NJ  07601      1
# 1163            2029 MORRIS AVE              UNION NJ  07083      1
# 1422             355 MARVIN AVE        HACKENSACK, NJ  07601      1
# 2255       210 RIVER STREET #24        HACKENSACK, NJ  07601      1
# 2272             189 SO PARK ST         HACKENSACK NJ  07601      1
# 2273              187 S PARK ST        HACKENSACK, NJ  07666      1
# 2274        183-185 SO. PARK ST        HACKENSACK, NJ  07601      1
# 2275              179 FIELD AVE  HASBROUCK HEIGHTS NJ  07604      1
# 2276           177 SO. PARK ST.        HACKENSACK, NJ  07601      1
# 2292           202 RUSSEL PLACE        HACKENSACK, NJ  07601      1
# 2328        90 PROSPECT AVE #4F        HACKENSACK, NJ  07601      1
# 2943    280-284 AMERICAN LEGION         HACKENSACK NJ  07601      1
# 2965           375 DOUGHTY BLVD            INWOOD, NY  11096      1
# 3001  1124 E RIDGEWOOD AVE #101         RIDGEWOOD, NJ  07450      1
# 3002                725 MAIN ST         HACKENSACK NJ  07601      1
# 3026            1000 TEANECK RD           TEANECK, NJ  07666      1
# 3069  1051 BLOOMFIELD AVE STE2A           CLIFTON, NJ  07012      1
# 3077    9 POLITO AVE SUITE#1010         LYNDHURST, NJ  07071      1
# 3388        297 RAILROAD AVENUE        HACKENSACK, NJ  07601      1
# 3492                 PO BOX 100         HACKENSACK NJ  07601      1
# 5978           321 EUCLID AVE S         HACKENSACK NJ  07601      1
# 5981             333 EUCLID AVE        HACKENSACK, NJ  07601      1
# 6122   450 WEST ANDERSON STREET         HACKENSACK NJ  07601      1
# 6419               278 ROUTE 34           MATAWAN, NJ  07747      1
# 7446                  98 BOX 88   RIDGEFIELD PARK, NJ  07660      1
# 7617               256 LOUIS ST        HACKENSACK, NJ  07601      1
# 7869             258 LINCOLN ST        HACKENSACK, NJ  07601      1
#
#                                         propertiesOwned  \
# 282                          [387A & 387B WILLIAMS AVE]
# 500                                  [182 BONHOMME AVE]
# 702   [31 JACKSON AVE, 33-35 JACKSON AVE, 37-41 JACK...
# 703   [31 JACKSON AVE, 33-35 JACKSON AVE, 37-41 JACK...
# 733                                   [10 VAN WETERING]
# 735                                  [115 SO RIVER ST.]
# 736                                [36 VAN WETERING PL]
# 862                           [101 KANSAS &46 SO STATE]
# 952                         [163 KANSAS ST & 47 HOBART]
# 957                     [108-112 FAIR ST, 74 MC KINLEY]
# 1053                                  [222 ELLEEN TERR]
# 1163                           [360 W PLEASANTVIEW AVE]
# 1422                             [MARVIN & PROSPECT AV]
# 2255                  [88 MC KINLEY ST, 170 SO PARK ST]
# 2272                                   [189 SO PARK ST]
# 2273                                   [187 SO PARK ST]
# 2274                                [183-85 SO PARK ST]
# 2275                                   [179 SO PARK ST]
# 2276                                   [177 SO PARK ST]
# 2292                                   [202 RUSSEL PL.]
# 2328                              [90 PROSPECT AVE #4F]
# 2943                        [280-84 AMERICAN LEGION DR]
# 2965                               [365 AMER LEGION DR]
# 3001          [ESSEX & ARCADIA RD, CAMBRIDGE TER SEC 5]
# 3002                                 [95-167 TRACY PL.]
# 3026                         [5-65 ARCADIA & 450 ESSEX]
# 3069                               [161-1631/2 MAIN ST]
# 3077                                [1 & 2 PARK AVENUE]
# 3388                              [295-97 RAILROAD AVE]
# 3492                             [215-17-21 SECOND ST.]
# 5978                                [321 SO EUCLID AVE]
# 5981                                [333 SO EUCLID AVE]
# 6122                                [448-50 W ANDERSON]
# 6419                         [140 GRAND & 50 FAIRMOUNT]
# 7446                                 [889-895 MAIN ST.]
# 7617                                  [256-58 LOUIS ST]
# 7869                                [256-58 LINCOLN ST]
#
#       getNumberPropertiesOwned                        propertyFullAddress  \
# 282                          1   387A & 387B WILLIAMS AVE, HACKENSACK, NJ
# 500                          1           182 BONHOMME AVE, HACKENSACK, NJ
# 702                          5    45 JACKSON AVE, UNIT #1, HACKENSACK, NJ
# 703                          5    45 JACKSON AVE, UNIT #2, HACKENSACK, NJ
# 733                          1            10 VAN WETERING, HACKENSACK, NJ
# 735                          1           115 SO RIVER ST., HACKENSACK, NJ
# 736                          1         36 VAN WETERING PL, HACKENSACK, NJ
# 862                          1       101 KANSAS &46 STATE, HACKENSACK, NJ
# 952                          1  163 KANSAS ST & 47 HOBART, HACKENSACK, NJ
# 957                          2               74 MC KINLEY, HACKENSACK, NJ
# 1053                         1            222 ELLEEN TERR, HACKENSACK, NJ
# 1163                         1     360 W PLEASANTVIEW AVE, HACKENSACK, NJ
# 1422                         1       MARVIN & PROSPECT AV, HACKENSACK, NJ
# 2255                         2             170 SO PARK ST, HACKENSACK, NJ
# 2272                         1             189 SO PARK ST, HACKENSACK, NJ
# 2273                         1             187 SO PARK ST, HACKENSACK, NJ
# 2274                         1          183-85 SO PARK ST, HACKENSACK, NJ
# 2275                         1             179 SO PARK ST, HACKENSACK, NJ
# 2276                         1             177 SO PARK ST, HACKENSACK, NJ
# 2292                         1             202 RUSSEL PL., HACKENSACK, NJ
# 2328                         1        90 PROSPECT AVE #4F, HACKENSACK, NJ
# 2943                         1  280-84 AMERICAN LEGION DR, HACKENSACK, NJ
# 2965                         1         365 AMER LEGION DR, HACKENSACK, NJ
# 3001                         2         ESSEX & ARCADIA RD, HACKENSACK, NJ
# 3002                         1           95-167 TRACY PL., HACKENSACK, NJ
# 3026                         1   5-65 ARCADIA & 450 ESSEX, HACKENSACK, NJ
# 3069                         1         161-1631/2 MAIN ST, HACKENSACK, NJ
# 3077                         1          1 & 2 PARK AVENUE, HACKENSACK, NJ
# 3388                         1        295-97 RAILROAD AVE, HACKENSACK, NJ
# 3492                         1          215-17-21 2ND ST., HACKENSACK, NJ
# 5978                         1          321 SO EUCLID AVE, HACKENSACK, NJ
# 5981                         1          333 SO EUCLID AVE, HACKENSACK, NJ
# 6122                         1          448-50 W ANDERSON, HACKENSACK, NJ
# 6419                         1   140 GRAND & 50 FAIRMOUNT, HACKENSACK, NJ
# 7446                         1           889-895 MAIN ST., HACKENSACK, NJ
# 7617                         1            256-58 LOUIS ST, HACKENSACK, NJ
# 7869                         1          256-58 LINCOLN ST, HACKENSACK, NJ
#
#      gCode
# 282   None
# 500   None
# 702   None
# 703   None
# 733   None
# 735   None
# 736   None
# 862   None
# 952   None
# 957   None
# 1053  None
# 1163  None
# 1422  None
# 2255  None
# 2272  None
# 2273  None
# 2274  None
# 2275  None
# 2276  None
# 2292  None
# 2328  None
# 2943  None
# 2965  None
# 3001  None
# 3002  None
# 3026  None
# 3069  None
# 3077  None
# 3388  None
# 3492  None
# 5978  None
# 5981  None
# 6122  None
# 6419  None
# 7446  None
# 7617  None
# 7869  None

# %%
# df.dropna(axis=0, subset=['gCode'], inplace=True)

# %% [markdown]
# ### dropping the addresses which returned None from the dataframe
# ### pickled hackensack dataframe as only the correctly geocoded addresses

# %%
df
# Out:
#      propertyLocation                           ownersName  \
# 0     25 MOONACHIE RD         TOWER ARCADIA COURT 2015 LLC
# 1      511 HUDSON ST.              REYES,JUAN C & HERMINIA
# 2       606 HUDSON ST    DURANTE, MICHAEL D & CARMENCITA Y
# 3       598 HUDSON ST  594 HUDSON STREET REALTY ASSOCIATES
# 4       608 HUDSON ST        O'CONNELL, MICHAEL & CATHLEEN
# ...               ...                                  ...
# 8227     33 S LAKE DR          WICKERSHEIM, ROBERT & CAROL
# 8228     31 S LAKE DR                        PEREZ,ADRIANA
# 8229     29 S LAKE DR      SILVESTRI, ANGELO J. & MADELINE
# 8230     27 S LAKE DR       RHODEN,SHEAN & SANCHEZ,SOLANYI
# 8231     21 S LAKE DR                     THORNTON, BONITA
#
#      ownersMailingAddress           cityStateZip  units    propertiesOwned  \
# 0     680 KINDERKAMACK RD  RIVER EDGE, NJ  07661      1  [25 MOONACHIE RD]
# 1           511 HUDSON ST  HACKENSACK, NJ  07601      1   [511 HUDSON ST.]
# 2           606 HUDSON ST  HACKENSACK, NJ  07601      1    [606 HUDSON ST]
# 3       598 HUDSON STREET  HACKENSACK, NJ  07601      1    [598 HUDSON ST]
# 4        62 GREENBRIAR RD     PARAMUS, NJ  07652      1    [608 HUDSON ST]
# ...                   ...                    ...    ...                ...
# 8227        126 CEDAR AVE   HACKENSACK NJ  07601      1    [33 SO LAKE DR]
# 8228        31 SO LAKE DR  HACKENSACK, NJ  07601      1    [31 SO LAKE DR]
# 8229         29 S LAKE DR   HACKENSACK NJ  07601      1    [29 SO LAKE DR]
# 8230         27 S LAKE DR  HACKENSACK, NJ  07601      1    [27 SO LAKE DR]
# 8231         21 S LAKE DR  HACKENSACK, NJ  07601      1    [21 SO LAKE DR]
#
#       getNumberPropertiesOwned              propertyFullAddress  \
# 0                            1  25 MOONACHIE RD, HACKENSACK, NJ
# 1                            1   511 HUDSON ST., HACKENSACK, NJ
# 2                            1    606 HUDSON ST, HACKENSACK, NJ
# 3                            1    598 HUDSON ST, HACKENSACK, NJ
# 4                            1    608 HUDSON ST, HACKENSACK, NJ
# ...                        ...                              ...
# 8227                         1     33 S LAKE DR, HACKENSACK, NJ
# 8228                         1     31 S LAKE DR, HACKENSACK, NJ
# 8229                         1     29 S LAKE DR, HACKENSACK, NJ
# 8230                         1     27 S LAKE DR, HACKENSACK, NJ
# 8231                         1     21 S LAKE DR, HACKENSACK, NJ
#
#                                                   gCode        Lat       Long
# 0     (25, Moonachie Road, Hackensack, Bergen County...  40.861991 -74.039175
# 1     (511, Hudson Street, Hackensack, Bergen County...  40.862308 -74.037843
# 2     (606, Hudson Street, Hackensack, Bergen County...  40.860612 -74.036937
# 3     (598, Hudson Street, Hackensack, Bergen County...  40.860758 -74.036995
# 4     (608, Hudson Street, Hackensack, Bergen County...  40.860576 -74.036923
# ...                                                 ...        ...        ...
# 8227  (33, South Lake Drive, North Hackensack, Hacke...  40.910849 -74.041346
# 8228  (31, South Lake Drive, North Hackensack, Hacke...  40.910830 -74.041258
# 8229  (29, South Lake Drive, North Hackensack, Hacke...  40.910811 -74.041169
# 8230  (27, South Lake Drive, North Hackensack, Hacke...  40.910792 -74.041081
# 8231  (21, South Lake Drive, North Hackensack, Hacke...  40.910767 -74.040812
#
# [8206 rows x 11 columns]

# %%
errors_df.propertyLocation.head(50)
# Out:
# 282    387A & 387B WILLIAMS AVE
# 434              212 SO MAIN ST
# 435           208-10 SO MAIN ST
# 500            182 BONHOMME AVE
# 525               52 REILLY CT.
# 526               54 REILLY CT.
# 527               56 REILLY CT.
# 528               58 REILLY CT.
# 529               55 REILLY CT.
# 530               57 REILLY CT.
# 531               51 REILLY CT.
# 532               53 REILLY CT.
# 533               47 REILLY CT.
# 534               49 REILLY CT.
# 547              186 SO MAIN ST
# 548              178 SO MAIN ST
# 559              206 SO MAIN ST
# 560              204 SO MAIN ST
# 561              202 SO MAIN ST
# 562              200 SO MAIN ST
# 563              194 SO MAIN ST
# 564              190 SO MAIN ST
# 568             158 SO STATE ST
# 574              217 SO MAIN ST
# 575              211 SO MAIN ST
# 576          197-209 SO MAIN ST
# 580              225 SO MAIN ST
# 612             143 SO STATE ST
# 613             147 SO STATE ST
# 614             150 SO STATE ST
# 615             148 SO STATE ST
# 616               105 TROAST ST
# 617               101 TROAST ST
# 618                99 TROAST ST
# 619            93-95 TROAST ST.
# 620                89 TROAST ST
# 621                87 TROAST ST
# 622                79 TROAST ST
# 623                77 TROAST ST
# 624                75 TROAST ST
# 625                73 TROAST ST
# 626           147-51 SO MAIN ST
# 627              155 SO MAIN ST
# 628              161 SO MAIN ST
# 641               108 TROAST ST
# 646               112 TROAST ST
# 648              100 TROAST ST.
# 654                84 TROAST ST
# 655                92 TROAST ST
# 656                82 TROAST ST
# Name: propertyLocation, dtype: object

# %%
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO MAIN', 'MAIN')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO STATE', 'STATE')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('REILLY', 'REILY')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO LAKE', 'S LAKE')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('TROAST', 'TROOST')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SPRING VALLEY', 'SPRING VALLEY AVE')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('NO PROSPECT', 'PROSPECT')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO PROSPECT', 'PROSPECT')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO SUMMIT', 'SUMMIT')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('DE WITT', 'DEWITT')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('FIRST', '1ST')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SECOND', '2ND')
# errors_df.propertyLocation = errors_df.propertyLocation.str.replace('THIRD', '3RD')

errors_df.propertyLocation = errors_df.propertyLocation.str.replace('SO PARK', 'S PARK')

# %%
errors_df.propertyLocation
# Out:
# 282      387A & 387B WILLIAMS AVE
# 500              182 BONHOMME AVE
# 702       45 JACKSON AVE, UNIT #1
# 703       45 JACKSON AVE, UNIT #2
# 733               10 VAN WETERING
# 735              115 SO RIVER ST.
# 736            36 VAN WETERING PL
# 862          101 KANSAS &46 STATE
# 952     163 KANSAS ST & 47 HOBART
# 957                  74 MC KINLEY
# 1053              222 ELLEEN TERR
# 1163       360 W PLEASANTVIEW AVE
# 1422         MARVIN & PROSPECT AV
# 2255                170 S PARK ST
# 2272                189 S PARK ST
# 2273                187 S PARK ST
# 2274             183-85 S PARK ST
# 2275                179 S PARK ST
# 2276                177 S PARK ST
# 2292               202 RUSSEL PL.
# 2328          90 PROSPECT AVE #4F
# 2943    280-84 AMERICAN LEGION DR
# 2965           365 AMER LEGION DR
# 3001           ESSEX & ARCADIA RD
# 3002             95-167 TRACY PL.
# 3026     5-65 ARCADIA & 450 ESSEX
# 3069           161-1631/2 MAIN ST
# 3077            1 & 2 PARK AVENUE
# 3388          295-97 RAILROAD AVE
# 3492            215-17-21 2ND ST.
# 5978            321 SO EUCLID AVE
# 5981            333 SO EUCLID AVE
# 6122            448-50 W ANDERSON
# 6419     140 GRAND & 50 FAIRMOUNT
# 7446             889-895 MAIN ST.
# 7617              256-58 LOUIS ST
# 7869            256-58 LINCOLN ST
# Name: propertyLocation, dtype: object

# %%
#df['propertyFullAddress'] = df['propertyLocation'] + ", HACKENSACK, NJ"

errors_df['propertyFullAddress'] = errors_df['propertyLocation'] + ", HACKENSACK, NJ"

# %%
#df['gCode'] = df.propertyFullAddress.apply(geolocator.geocode)

errors_df['gCode'] = errors_df.propertyFullAddress.apply(geolocator.geocode)

# %%
# geocode_errors = [i for i,e in enumerate(df.gCode) if e == None]

geocode_errors = [i for i,e in enumerate(errors_df.gCode) if e == None]

# %%
# df.iloc[geocode_errors]

# errors_df = df.iloc[geocode_errors].copy()

errors_df.iloc[geocode_errors].head(50)
# Out:
#                propertyLocation                           ownersName  \
# 282    387A & 387B WILLIAMS AVE     TORNAMBE, SALVATORE G & PAOLO JR
# 500            182 BONHOMME AVE                     TENEZACA, MANUEL
# 702     45 JACKSON AVE, UNIT #1                     JACKSON PINK LLC
# 703     45 JACKSON AVE, UNIT #2                     JACKSON PINK LLC
# 733             10 VAN WETERING  PEREZ,JAIME & TERESA C/O ALBA PEREZ
# 735            115 SO RIVER ST.    CHESSARI, FRANK & MARY ( TRUSTEE)
# 736          36 VAN WETERING PL                     PUNTASECCA, RORY
# 862        101 KANSAS &46 STATE                  SIGUENCIA, TRANSITO
# 952   163 KANSAS ST & 47 HOBART       SOLIS,GILMO F & TORNO,BERNARDO
# 957                74 MC KINLEY                  TAMAY, LUIS & MARIA
# 1053            222 ELLEEN TERR        222 ELLEEN TERRACE, LLC %MELI
# 1163     360 W PLEASANTVIEW AVE    ROYAL TOWERS ASSOC % SALEM MTG CO
# 1422       MARVIN & PROSPECT AV                  CASAMENTI, ALPHONSO
# 2274           183-85 S PARK ST           CAMPOVERDE, EDISON & ANA P
# 2292             202 RUSSEL PL.          MORQUECHO, GABRIEL & GLORIA
# 2328        90 PROSPECT AVE #4F    COOPER,JAMES C. & CUONO, LORRAINE
# 2943  280-84 AMERICAN LEGION DR           FRANCISCO APARTMENTS, INC.
# 2965         365 AMER LEGION DR                     GANZ, JOEL TRSTE
# 3001         ESSEX & ARCADIA RD              SDK SUMMIT GARDENS, LLC
# 3002           95-167 TRACY PL.     GLEN VIEW ASSOC. C/O HANSON MGMT
# 3026   5-65 ARCADIA & 450 ESSEX             TULANE HOLDINGS LLC ETAL
# 3069         161-1631/2 MAIN ST           MAIN STREET HACKENSACK LLC
# 3077          1 & 2 PARK AVENUE    R&H HACKENSACK URBAN RENEWAL, LLC
# 3388        295-97 RAILROAD AVE                        PERSON, GARRY
# 3492          215-17-21 2ND ST.          FAO GARDENS ASSOCIATES, LLC
# 5978          321 SO EUCLID AVE           TROIANO, MICHAEL & VALERIE
# 5981          333 SO EUCLID AVE                    RICHMOND, MAUREEN
# 6122          448-50 W ANDERSON                    JMRC HOLDING, LLC
# 6419   140 GRAND & 50 FAIRMOUNT              FERRARO PROPERTIES, LLC
# 7446           889-895 MAIN ST.                A & K ASSOCIATES, LLC
# 7617            256-58 LOUIS ST                    LEWIS, MARGARET O
# 7869          256-58 LINCOLN ST                LUPPINO, LOUIS & ANNA
#
#            ownersMailingAddress                cityStateZip  units  \
# 282              410 TAYLOR AVE       HACKENSACK, NJ  07601      1
# 500             182 BONHOMME ST       HACKENSACK, NJ  07601      1
# 702      224 LINDA VISTA AVENUE    NORTH HALEDON, NJ  07508      1
# 703      224 LINDA VISTA AVENUE    NORTH HALEDON, NJ  07508      1
# 733           248 MARVIN AVENUE        HACKENSACK NJ  07601      1
# 735           248 PHILLIPS AVE.  SOUTH HACKENSACK NJ  07606      1
# 736          36 VAN WETERING PL       HACKENSACK, NJ  07601      1
# 862               101 KANSAS ST       HACKENSACK, NJ  07601      1
# 952               163 KANSAS ST       HACKENSACK, NJ  07601      1
# 957                 108 FAIR ST       HACKENSACK, NJ  07601      1
# 1053                 PO BOX 100       HACKENSACK, NJ  07601      1
# 1163            2029 MORRIS AVE             UNION NJ  07083      1
# 1422             355 MARVIN AVE       HACKENSACK, NJ  07601      1
# 2274        183-185 SO. PARK ST       HACKENSACK, NJ  07601      1
# 2292           202 RUSSEL PLACE       HACKENSACK, NJ  07601      1
# 2328        90 PROSPECT AVE #4F       HACKENSACK, NJ  07601      1
# 2943    280-284 AMERICAN LEGION        HACKENSACK NJ  07601      1
# 2965           375 DOUGHTY BLVD           INWOOD, NY  11096      1
# 3001  1124 E RIDGEWOOD AVE #101        RIDGEWOOD, NJ  07450      1
# 3002                725 MAIN ST        HACKENSACK NJ  07601      1
# 3026            1000 TEANECK RD          TEANECK, NJ  07666      1
# 3069  1051 BLOOMFIELD AVE STE2A          CLIFTON, NJ  07012      1
# 3077    9 POLITO AVE SUITE#1010        LYNDHURST, NJ  07071      1
# 3388        297 RAILROAD AVENUE       HACKENSACK, NJ  07601      1
# 3492                 PO BOX 100        HACKENSACK NJ  07601      1
# 5978           321 EUCLID AVE S        HACKENSACK NJ  07601      1
# 5981             333 EUCLID AVE       HACKENSACK, NJ  07601      1
# 6122   450 WEST ANDERSON STREET        HACKENSACK NJ  07601      1
# 6419               278 ROUTE 34          MATAWAN, NJ  07747      1
# 7446                  98 BOX 88  RIDGEFIELD PARK, NJ  07660      1
# 7617               256 LOUIS ST       HACKENSACK, NJ  07601      1
# 7869             258 LINCOLN ST       HACKENSACK, NJ  07601      1
#
#                                         propertiesOwned  \
# 282                          [387A & 387B WILLIAMS AVE]
# 500                                  [182 BONHOMME AVE]
# 702   [31 JACKSON AVE, 33-35 JACKSON AVE, 37-41 JACK...
# 703   [31 JACKSON AVE, 33-35 JACKSON AVE, 37-41 JACK...
# 733                                   [10 VAN WETERING]
# 735                                  [115 SO RIVER ST.]
# 736                                [36 VAN WETERING PL]
# 862                           [101 KANSAS &46 SO STATE]
# 952                         [163 KANSAS ST & 47 HOBART]
# 957                     [108-112 FAIR ST, 74 MC KINLEY]
# 1053                                  [222 ELLEEN TERR]
# 1163                           [360 W PLEASANTVIEW AVE]
# 1422                             [MARVIN & PROSPECT AV]
# 2274                                [183-85 SO PARK ST]
# 2292                                   [202 RUSSEL PL.]
# 2328                              [90 PROSPECT AVE #4F]
# 2943                        [280-84 AMERICAN LEGION DR]
# 2965                               [365 AMER LEGION DR]
# 3001          [ESSEX & ARCADIA RD, CAMBRIDGE TER SEC 5]
# 3002                                 [95-167 TRACY PL.]
# 3026                         [5-65 ARCADIA & 450 ESSEX]
# 3069                               [161-1631/2 MAIN ST]
# 3077                                [1 & 2 PARK AVENUE]
# 3388                              [295-97 RAILROAD AVE]
# 3492                             [215-17-21 SECOND ST.]
# 5978                                [321 SO EUCLID AVE]
# 5981                                [333 SO EUCLID AVE]
# 6122                                [448-50 W ANDERSON]
# 6419                         [140 GRAND & 50 FAIRMOUNT]
# 7446                                 [889-895 MAIN ST.]
# 7617                                  [256-58 LOUIS ST]
# 7869                                [256-58 LINCOLN ST]
#
#       getNumberPropertiesOwned                        propertyFullAddress  \
# 282                          1   387A & 387B WILLIAMS AVE, HACKENSACK, NJ
# 500                          1           182 BONHOMME AVE, HACKENSACK, NJ
# 702                          5    45 JACKSON AVE, UNIT #1, HACKENSACK, NJ
# 703                          5    45 JACKSON AVE, UNIT #2, HACKENSACK, NJ
# 733                          1            10 VAN WETERING, HACKENSACK, NJ
# 735                          1           115 SO RIVER ST., HACKENSACK, NJ
# 736                          1         36 VAN WETERING PL, HACKENSACK, NJ
# 862                          1       101 KANSAS &46 STATE, HACKENSACK, NJ
# 952                          1  163 KANSAS ST & 47 HOBART, HACKENSACK, NJ
# 957                          2               74 MC KINLEY, HACKENSACK, NJ
# 1053                         1            222 ELLEEN TERR, HACKENSACK, NJ
# 1163                         1     360 W PLEASANTVIEW AVE, HACKENSACK, NJ
# 1422                         1       MARVIN & PROSPECT AV, HACKENSACK, NJ
# 2274                         1           183-85 S PARK ST, HACKENSACK, NJ
# 2292                         1             202 RUSSEL PL., HACKENSACK, NJ
# 2328                         1        90 PROSPECT AVE #4F, HACKENSACK, NJ
# 2943                         1  280-84 AMERICAN LEGION DR, HACKENSACK, NJ
# 2965                         1         365 AMER LEGION DR, HACKENSACK, NJ
# 3001                         2         ESSEX & ARCADIA RD, HACKENSACK, NJ
# 3002                         1           95-167 TRACY PL., HACKENSACK, NJ
# 3026                         1   5-65 ARCADIA & 450 ESSEX, HACKENSACK, NJ
# 3069                         1         161-1631/2 MAIN ST, HACKENSACK, NJ
# 3077                         1          1 & 2 PARK AVENUE, HACKENSACK, NJ
# 3388                         1        295-97 RAILROAD AVE, HACKENSACK, NJ
# 3492                         1          215-17-21 2ND ST., HACKENSACK, NJ
# 5978                         1          321 SO EUCLID AVE, HACKENSACK, NJ
# 5981                         1          333 SO EUCLID AVE, HACKENSACK, NJ
# 6122                         1          448-50 W ANDERSON, HACKENSACK, NJ
# 6419                         1   140 GRAND & 50 FAIRMOUNT, HACKENSACK, NJ
# 7446                         1           889-895 MAIN ST., HACKENSACK, NJ
# 7617                         1            256-58 LOUIS ST, HACKENSACK, NJ
# 7869                         1          256-58 LINCOLN ST, HACKENSACK, NJ
#
#      gCode
# 282   None
# 500   None
# 702   None
# 703   None
# 733   None
# 735   None
# 736   None
# 862   None
# 952   None
# 957   None
# 1053  None
# 1163  None
# 1422  None
# 2274  None
# 2292  None
# 2328  None
# 2943  None
# 2965  None
# 3001  None
# 3002  None
# 3026  None
# 3069  None
# 3077  None
# 3388  None
# 3492  None
# 5978  None
# 5981  None
# 6122  None
# 6419  None
# 7446  None
# 7617  None
# 7869  None

# %% [markdown]
# ### Test to see if address geocodes with certain characters removed

# %%
# df.to_pickle('hackensack.pkl')
# errors_df.to_pickle('errors_df.pkl')

# %%
geolocator.geocode('448-50 ANDERSON, HACKENSACK, NJ')
# Out:
# Location(448, West Anderson Street, Hackensack, Bergen County, New Jersey, 07601, United States, (40.900954561797754, -74.05488235955056, 0.0))

# %% [markdown]
# ## initially errors_df will be a copy of df…
# ## subsequently errors_df will be reassigned to a copy of errors_df's errors

# %% [markdown]
# ## return errors cleaned this round

# %%
errors_df.dropna(axis=0, subset=['gCode'])
# Out:
#      propertyLocation                           ownersName  \
# 2255    170 S PARK ST                HACKENSACK NORSE, LLC
# 2272    189 S PARK ST    BACOTE,JANICE & RICHARDSON,CHANDA
# 2273    187 S PARK ST         BERGEN REALTY MANAGEMENT LLC
# 2275    179 S PARK ST    VELAZQUEZ,JESUS & MARGARET & MARY
# 2276    177 S PARK ST  DEWINDT,DODLEY R &LYNETH E ANDERSON
#
#       ownersMailingAddress                 cityStateZip  units  \
# 2255  210 RIVER STREET #24        HACKENSACK, NJ  07601      1
# 2272        189 SO PARK ST         HACKENSACK NJ  07601      1
# 2273         187 S PARK ST        HACKENSACK, NJ  07666      1
# 2275         179 FIELD AVE  HASBROUCK HEIGHTS NJ  07604      1
# 2276      177 SO. PARK ST.        HACKENSACK, NJ  07601      1
#
#                         propertiesOwned  getNumberPropertiesOwned  \
# 2255  [88 MC KINLEY ST, 170 SO PARK ST]                         2
# 2272                   [189 SO PARK ST]                         1
# 2273                   [187 SO PARK ST]                         1
# 2275                   [179 SO PARK ST]                         1
# 2276                   [177 SO PARK ST]                         1
#
#                 propertyFullAddress  \
# 2255  170 S PARK ST, HACKENSACK, NJ
# 2272  189 S PARK ST, HACKENSACK, NJ
# 2273  187 S PARK ST, HACKENSACK, NJ
# 2275  179 S PARK ST, HACKENSACK, NJ
# 2276  177 S PARK ST, HACKENSACK, NJ
#
#                                                   gCode
# 2255  (170, South Park Street, Hackensack, Bergen Co...
# 2272  (189, South Park Street, Hackensack, Bergen Co...
# 2273  (187, South Park Street, Hackensack, Bergen Co...
# 2275  (179, South Park Street, Hackensack, Bergen Co...
# 2276  (177, South Park Street, Hackensack, Bergen Co...

# %% [markdown]
# ## append errors_df values which are not none to the df, in place, before pickling the df

# %%
df.append(errors_df.dropna(axis=0, subset=['gCode'])).to_pickle('hackensack.pkl')

# %%
errors_df = errors_df.iloc[geocode_errors].copy()

# %%
errors_df.to_pickle('errors_df.pkl')
