# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
geolocator = Nominatim(user_agent="myGeolocator", timeout=1)
from paterson_repl_dict import paterson_repl_dict

def getPropertiesOwned(owner=str):
    return df[df.ownersName == owner]['propertyLocation'].unique().tolist()

# number of times property appears in first column
def getUnits(address=str):
    return len(df[df.propertyLocation == address])

# number of the properties owned by the given owner
def getNumberOwned(owner=str):
    return df[(df.ownersName == owner)]['propertyLocation'].count()

# %%
os.getcwd()
# Out:
# '/Users/kylereaves/Desktop/landlord_data/Paterson'

# %%
os.chdir('/Users/kylereaves/Desktop/landlord_data/Paterson')

# %%
os.listdir()
# Out:
# ['paterson.ipynb',
#  '.DS_Store',
#  'paterson.pkl',
#  '1608monm002917.csv',
#  'errors_df.pkl',
#  '1608monm174855.csv',
#  '1608monm210517.csv']

# %%
# df = pd.read_csv('1608monm174855.csv', usecols=[
#                  "Property Location", "Owner's Name", "Owner's Mailing Address", "City/State/Zip"])
# df.rename(columns={'Property Location': 'propertyLocation',
#                    "Owner's Name": "ownersName",
#                    "Owner's Mailing Address": "ownersMailingAddress",
#                    "City/State/Zip": "cityStateZip"}, inplace=True)
# df['units'] = [getUnits(address) for address in df.propertyLocation]
# df['propertiesOwned'] = [getPropertiesOwned(owner) for owner in df.ownersName]
# df['getNumberPropertiesOwned'] = [getNumberOwned(owner) for owner in df.ownersName]

# %%
df['propertyFullAddress'] = df.propertyLocation + ", PATERSON, NJ"

# %%
df = pd.read_pickle('paterson.pkl')
errors_df = pd.read_pickle('errors_df.pkl')

# %%
df
# Out:
#           propertyLocation                       ownersName  \
# 0             98 HOPPER ST  VILLANUEVA,RAUL A & LUGO,JUSTIN
# 1             283 N 4TH ST              HENRIQUEZ, JENNY I.
# 2             281 N 4TH ST                     SILVA,OVIDIO
# 3             279 N 4TH ST        PLANE TREE PROPERTIES LLC
# 4             277 N 4TH ST        277 NORTH 4TH STREET, LLC
# ...                    ...                              ...
# 18920  911-913 MADISON AVE     HUERTAS, JOSE & LIDUVINA H/W
# 18921  909-911 MADISON AVE                   RAMOS, RUPERTO
# 18922      907 MADISON AVE               MOLINA,FRANCISCO J
# 18923  903-905 MADISON AVE          MIGUEL D. GARCIA CEPEDA
# 18924  901-903 MADISON AVE       MORAN, MANUEL & ASENET H/W
#
#             ownersMailingAddress          cityStateZip  units  \
# 0                   98 HOPPER ST    PATERSON NJ  07522      1
# 1             56 PATERSON AVENUE   PATERSON, NJ  07522      1
# 2                56 PATERSON AVE    PATERSON,NJ  07522      1
# 3                    PO BOX 1085     CLIFTON,NJ  07014      1
# 4      56 HAMBURG TURNPIKE # 253  RIVERDALE, NJ  07547      1
# ...                          ...                   ...    ...
# 18920            911 MADISON AVE    PATERSON NJ  07501      1
# 18921          258 AUTUMN STREET    PASSAIC, NJ  07055      1
# 18922            907 MADISON AVE    PATERSON NJ  07503      1
# 18923         905 MADISON AVENUE    PATERSON NJ  07501      1
# 18924            901 MADISON AVE    PATERSON NJ  07501      1
#
#                                         propertiesOwned  \
# 0                                        [98 HOPPER ST]
# 1                                        [283 N 4TH ST]
# 2      [281 N 4TH ST, 7 CIRCLE AVE, 54-56 PATERSON AVE]
# 3                                        [279 N 4TH ST]
# 4                                        [277 N 4TH ST]
# ...                                                 ...
# 18920                             [911-913 MADISON AVE]
# 18921                             [909-911 MADISON AVE]
# 18922                                 [907 MADISON AVE]
# 18923                             [903-905 MADISON AVE]
# 18924                             [901-903 MADISON AVE]
#
#        getNumberPropertiesOwned                propertyFullAddress  \
# 0                             1         98 HOPPER ST, PATERSON, NJ
# 1                             1         283 N 4TH ST, PATERSON, NJ
# 2                             3         281 N 4TH ST, PATERSON, NJ
# 3                             1         279 N 4TH ST, PATERSON, NJ
# 4                             1         277 N 4TH ST, PATERSON, NJ
# ...                         ...                                ...
# 18920                         1  911-913 MADISON AVE, PATERSON, NJ
# 18921                         1  909-911 MADISON AVE, PATERSON, NJ
# 18922                         1      907 MADISON AVE, PATERSON, NJ
# 18923                         1  903-905 MADISON AVE, PATERSON, NJ
# 18924                         1  901-903 MADISON AVE, PATERSON, NJ
#
#                                                    gCode        Lat       Long
# 0      (98, Hopper Street, Prospect Park, Passaic Cou...  40.932479 -74.169429
# 1      (283, North 4th Street, Paterson, Passaic Coun...  40.931718 -74.169154
# 2      (281, North 4th Street, Paterson, Passaic Coun...  40.931694 -74.169185
# 3      (279, North 4th Street, Paterson, Passaic Coun...  40.931670 -74.169217
# 4      (277, North 4th Street, Paterson, Passaic Coun...  40.931646 -74.169249
# ...                                                  ...        ...        ...
# 18920  (911, Madison Avenue, Paterson, Passaic County...  40.909642 -74.156399
# 18921  (909, Madison Avenue, Paterson, Passaic County...  40.909698 -74.156381
# 18922  (907, Madison Avenue, Paterson, Passaic County...  40.909754 -74.156363
# 18923  (903, Madison Avenue, Paterson, Passaic County...  40.910028 -74.156277
# 18924  (901, Madison Avenue, Paterson, Passaic County...  40.910062 -74.156266
#
# [18199 rows x 11 columns]

# %%
errors_df.propertyLocation.unique()
# Out:
# array(['PT 151 NORTH 1ST ST', 'PT 145 NORTH 1ST ST',
#        'PT 141 NORTH 1ST ST', '137 N 1ST ST 1/2',
#        '2 HABITAT WAY (N 2ND ST)', '1 HABITAT WAY (N 2ND ST)',
#        '4 HABITAT WAY (N 2ND ST)', '6 HABITAT WAY (N 2ND ST)',
#        '8 HABITAT WAY (N 2ND ST)', '10 HABITAT WAY (N 2ND ST)',
#        '12 HABITAT WAY (N 2ND ST)', '14 HABITAT WAY (N 2ND ST)',
#        '16 HABITAT WAY (N 2ND ST)', '18 HABITAT WAY (N 2ND ST)',
#        '20 HABITAT WAY (N 2ND ST)', '26 HABITAT WAY (N 2ND ST)',
#        '28 HABITAT WAY (N 2ND ST)', '30 HABITAT WAY (N 2ND ST)',
#        '32 HABITAT WAY (N 2ND ST)', '100 PT-102 N 2ND ST.',
#        'PT-102-PT104 N 2ND ST', '130 N 1ST ST CV', '56-62 N STRAIGHT ST',
#        '10 WATSON ST', '22 WATSON ST', '24 WATSON ST', '30 WATSON ST',
#        '32 WATSON ST', '34 WATSON ST', '36 WATSON ST', '38 WATSON ST',
#        '40 WATSON ST', '42 WATSON ST', '44 WATSON ST', '46 WATSON ST',
#        'PT 46-48 E MAIN ST', '15 WATSON ST', '23 WATSON ST',
#        '29 WATSON ST', '10-12 N STRAIGHT ST', '41-43 WATSON ST',
#        '39 WATSON ST', '37 WATSON ST', '35 WATSON ST', '33 WATSON ST',
#        '7-9 N STRAIGHT ST', '13-15 N STRAIGHT ST', '55-57 NORTH 1ST',
#        '15 HOLSMAN ST RRS', '11-15 HOLSMAN ST FT', '23 PIERCEY ST',
#        '17 PIERCEY ST', '31 PT 33 N 6TH ST', 'PT33-35 NORTH 6TH ST',
#        'PT33-PT35 N 4TH ST', 'PT31-PT33 N 4TH ST', 'PT27-PT31 N 4TH ST',
#        'PT23-PT27 N 4TH ST', '13-PT15 N 4TH ST', 'PT15-17 N 4TH ST',
#        '30- PT32 N 5TH ST', 'PT32-34 N 5TH ST',
#        '1/2 98-100 NORTH 11TH ST', '96-1/2 98 NORTH 11TH ST',
#        '129-PT131 N 9TH ST', 'PT131-PT135 N 9TH ST',
#        'PT 130-132 N 10TH ST', '132-PT134 N 10TH ST', '109 N0RTH 4TH ST',
#        'PT 68-74 N 3RD ST', '66-PT68 N 3RD ST', '1 CIRCLE AVE RRS',
#        'FTS 78 N 5TH ST', 'RRS 78 N 5TH ST', '49-PT51 NORTH 4TH ST',
#        'PT51-PT55 NORTH 4TH ST', 'PT55-57 NORTH 4TH ST',
#        '67-69 N0RTH 5TH ST', '49-PT 51 N 6TH ST',
#        'FT.111-PT 113 N.7TH ST', '162-PT164 NORTH 7TH ST',
#        'PT164-166 NORTH 7TH ST', 'PT 127-129 N 3RD ST',
#        'PT 125-127 N 3RD ST', 'PT 144-146 N.4TH ST',
#        '115-PT117 N.11TH ST', 'PT117-119 N.11TH ST',
#        '100-PT-104 OXFORD ST', 'PT 17-19 OXFORD ST',
#        '15- PT 17 OXFORD ST', 'PT 537-539 TOTOWA AVE',
#        'PT 21-23 NORTH 7TH ST', '57-63 HOPE ST', '49-55 HOPE ST',
#        '49-63 HOPE ST', '53-PT57 GARRISON ST', 'PT57-59 GARRISON ST',
#        '273-277 W BROADWAY', '224 1/2 226 WAYNE AVE',
#        '1/2 226-228 WAYNE AVE', '391-1/2 393 UNION AVE',
#        'PT 407-PT411 UNION AVE', '110-PT112 REDWOOD AVE',
#        'PT 112-114 REDWOOD AVE', 'FRTS 32-34 SHERIDAN AVE',
#        'RRS 32-34 SHERIDAN AVE', 'BOSSHART TRACT',
#        'PT.237-PT.239 KEARNEY ST', '233-PT.237 KEARNEY ST',
#        '280-298 WAYNE AVE', 'PT245-247 WAYNE AVE',
#        'FTS 241-243 WAYNE AVE', '311-349 REDWOOD AVE',
#        '273-309 REDWOOD AVE', '153-271 REDWOOD AVE',
#        'PT 400 - PT 406 JASPER ST', '406-414 KEARNEY ST',
#        '13 ALDEN TR CV', '11 ALDEN TR CV', '9 ALDEN TR CV',
#        '7 ALDEN TR CV', '5 ALDEN TR CV', '1 ALDEN TR CV',
#        '15 ALDEN TR CV', '20 ALDEN TR CV', '16 ALDEN TR CV',
#        '14 ALDEN TR CV', '12 ALDEN TR CV', '10 ALDEN TR CV',
#        '8 ALDEN TR CV', '6 ALDEN TR CV', '4 ALDEN TR CV', '2 ALDEN TR CV',
#        'FTS 12-16 GRANITE AVE', '466-470 PREAKNESS AVE',
#        'PT 271-273 RYERSON AVE', '269-PT 271 RYERSON AVE',
#        '262-280 CHAMBERLAIN AVE', '387-391 PREAKNESS AVE',
#        '375-383 PREAKNESS AVE', '398-404 EDMUND AVE',
#        '463-473 PREAKNESS AVE', 'PT 271-273 EDMUND AVE',
#        '232-PT 234 PREAKNESS AVE', 'PTS 234-238 PREAKNESS AVE',
#        'PTS 238-240 PREAKNESS AVE', 'PT 242-244 PREAKNESS AVE',
#        '23PT 25 RYERSON AVE', 'PT25-27 RYERSON AVE',
#        '.73-175 PREAKNESS AVE', '10 DON BOSCO AVE', '12-16 DON BOSCO AVE',
#        '18-22 DON BOSCO AVE', '24-26 DON BOSCO AVE',
#        '26-28 DON BOSCO AVE', '30-32 DON BOSCO AVE',
#        '34-36 DON BOSCO AVE', '38-42 DON BOSCO AVE',
#        '44-48 DON BOSCO AVE', '50-52 DON BOSCO AVE',
#        '54-56 DON BOSCO AVE', '58-60 DON BOSCO AVE',
#        '31-33 DON BOSCO AVE', '27-29 DON BOSCO AVE',
#        '19-21 DON BOSCO AVE', '15-17 DON BOSCO AVE',
#        '11-13 DON BOSCO AVE', '219 1/2-221 WALNUT ST',
#        '1/2 221-223 WALNUT ST', 'PT 153-161 MAPLE ST',
#        'PT 53-57 LENOX AVE', '15-17 RIVER TR', '8-9 RIVER TR',
#        '6-7 RIVER TR', '273-277 EMERSON AVE', '48-54 E 13TH ST. UNIT 1',
#        '48-54 E 13TH ST. UNIT 2', '48-54 E 13TH ST. UNIT 3',
#        '48-54 E 13TH ST. UNIT 4', '48-54 E 13TH ST. UNIT 5',
#        '48-54 E 13TH ST. UNIT 6', '48-54 E 13TH ST. UNIT 7',
#        '48-54 E 13TH ST. UNIT 8', '48-54 E 13TH ST. UNIT 9',
#        '69-71 E 14TH ST', '672-676 RIVER ST', 'REARS 7-9 2ND AVE',
#        '1/2 56-60 MADISON AVE', '54-1/2 56 MADISON AVE',
#        '285 3/5-289 5TH AVE', 'PT141 - 145 4TH AVE',
#        '212-PT 216 E 23RD ST', '113 PT.115 E. 22ND ST',
#        '126-PT130 E 23RD ST', 'PT130-132 E 23RD ST', '429 PT 431 6TH AVE',
#        'PT 431-433 6TH AVE', '175-1/2 177 EAST 24TH ST',
#        'PT 257-PT 259 E. 25TH ST.', '273-277 E 28TH ST',
#        '335-PT 339 EAST 18TH ST', '342-PT344 EAST 19TH ST',
#        '141-143 7TH AVE FRTS', 'FRTS. 334-336 E 16TH ST',
#        'PT 222-224 EAST 16TH ST', '239-PT 241 EAST 17TH ST',
#        'PT241-243 EAST 17TH ST', 'PT 89-PT 91 8TH AVE',
#        '231-PT 233 WARREN ST', 'PT 233-235 WARREN ST',
#        '400 RIVER ST UNIT 1', '400 RIVER ST UNIT 2',
#        '400 RIVER ST UNIT 3', '399-PT 403 RIVER ST',
#        'PT6-RR12 PARK PLACE', '2-4 GRAHAM AVE', '6 GRAHAM AVE',
#        '8 GRAHAM AVENUE', '10 GRAHAM AVENUE', '16 GRAHAM AVE',
#        '30-36 GRAHAM AVE', '33-35 GRAHAM AVE', '31-33 GRAHAM AVE',
#        '21 GRAHAM AVE', '13 GRAHAM AVENUE', '11 GRAHAM AVE',
#        '9 GRAHAM AVE', '7 GRAHAM AVE', '5 GRAHAM AVE', '3 GRAHAM AVE',
#        '1 GRAHAM AVE', '50-52 GRAHAM AVE', '49-51 GRAHAM AVE',
#        '43 GRAHAM AVE', '69 GRAHAM AVE', '67 GRAHAM AVE', '65 GRAHAM AVE',
#        '63 GRAHAM AVE', '59 GRAHAM AVE', '62-64 GRAHAM AVE',
#        '66 GRAHAM AVE', '70 GRAHAM AVE', '72 GRAHAM AVE',
#        '74-1/2 76 KEEN ST', '1/2 76-78 KEEN ST', '78-80 GRAHAM AVE',
#        '82 GRAHAM AVE', '84 GRAHAM AVE', '86 GRAHAM AVE', '77 GRAHAM AVE',
#        '91 GRAHAM AVE', '89 GRAHAM AVE', '87 GRAHAM AVE', '85 GRAHAM AVE',
#        '81-83 GRAHAM AVE', '79-81 GRAHAM AVE', '100 GRAHAM AVE',
#        '102-104 GRAHAM AVE', '104-106 GRAHAM AVE', '106-108 GRAHAM AVE',
#        '108-110 GRAHAM AVE', '112 GRAHAM AVE', '163-165 MONTGOMERY PL',
#        '161-163 MONTGOMERY PL', '157-159 MONTGOMERY PL',
#        '155-157 MONTGOMERY PL', '153-155 MONTGOMERY PL',
#        '135-137 MONTGOMERY PL', '97-99 GRAHAM AVE', '149-151 GRAHAM AVE',
#        '147-149 GRAHAM AVE', '145-147 GRAHAM AVE', '141-143 GRAHAM AVE',
#        '139-141 GRAHAM AVE', '137-139 GRAHAM AVE', '129-131 GRAHAM AVE',
#        '127-129 GRAHAM AVE', '125-127 GRAHAM AVE', '125 GRAHAM AVE',
#        '121-123 GRAHAM AVE', '119-121 GRAHAM AVE',
#        '117-119 GRAHAM AVENUE', '181-183 MONTGOMERY PL',
#        '109-111 GRAHAM AVE', '107-109 GRAHAM AVE', '105-107 GRAHAM AVE',
#        '101-103 GRAHAM AVE', '99-101 GRAHAM AVE', '175-177 GRAHAM AVE',
#        '187-189 GRAHAM AVE', '185-187 GRAHAM AVE', '183-185 GRAHAM AVE',
#        '179-181 GRAHAM AVE', '158-PT160 GRAHAM AVE',
#        '160-164 GRAHAM AVENUE', '164-166 GRAHAM AVE',
#        '166-170 GRAHAM AVE', '138-142 GRAHAM AVE', '142-144 GRAHAM AVE',
#        '148-150 GRAHAM AVE', '152 GRAHAM AVE', '416-PT. 418 E 25TH ST',
#        'PT 418-PT 420 E 25TH ST', '443-445 E24TH ST', '347-361 E 27TH ST',
#        '387-393 11TH AVE', '565-569 E 22ND ST',
#        'PT575-PT577 EAST 23RD ST', 'PT 571-PT573 EAST 23RD ST',
#        'PT 569-PT573 EAST 23RD ST', '377-383 12TH AVE',
#        '398-404 12TH AVE', '595-609 BROADWAY', '198 GRAHAM AVE',
#        '200 GRAHAM AVE', '202-204 GRAHAM AVE', 'FRT. 276 GOVERNOR ST',
#        '197 GRAHAM AVE', '235 GRAHAM AVE', '192-228 GODWIN AVE',
#        '239 GRAHAM AVE', '237 GRAHAM AVENUE', '310-312 HAMILTONN AVENUE',
#        '261-263 GRAHAM AVE', '265 GRAHAM AVE', '267 GRAHAM AVE',
#        '269 GRAHAM AVE', '271 GRAHAM AVE', '429-437 BROADWAY',
#        '264-266 GRAHAM AVE', '175 BROAWDAY', '637-643 14TH AVE',
#        '558-562 14TH AVE', '688-692 E 26TH ST',
#        'PT 692- PT 694 EAST 26TH', 'PT 694-696 E 26TH ST',
#        '698-702 E 26TH ST', 'PT.775-RRS779-785 E.23RD',
#        '690-692 E 28TH ST', 'PT.728-730 E.28TH ST',
#        '681-683 MARKET ST FTS', '402 GRAHAM AVE', '404 GRAHAM AVE',
#        '406 GRAHAM AVE', '408 GRAHAM AVE', '410 GRAHAM AVE',
#        '412 GRAHAM AVE', '419 GRAHAM AVE', '417 GRAHAM AVE',
#        '415 GRAHAM AVE', '413 GRAHAM AVE', '409 GRAHAM AVE',
#        '407 GRAHAM AVE', '405 GRAHAM AVE', '403 GRAHAM AVE',
#        '401 GRAHAM AVE', '792-798 E 19TH ST', '398-406 BROADWAY',
#        'PT 163- PT165 16TH AVE', 'PT 165- 167 16TH AVE',
#        'PT.309-311 VAN HOUTEN ST', 'PT 338-340 ELLISON ST',
#        'MILL PLOT 18-MARKET ST', 'MILL PLOT 18 - MARKET ST',
#        'MILPLOT 18 - MARKET ST', 'MILL PLOT 18 MARKET ST',
#        '183-185 MC BRIDE AVE', '171-175 MC BRIDE AVE',
#        '33-PT 35 HOXEY ST', '211-213 MC BRIDE AVE', '235 MC BRIDE AVE',
#        '231-233 MC BRIDE AVE', '227-229 MC BRIDE AVE',
#        '329-331 MC BRIDE AVE', '325-327 MC BRIDE AVE',
#        '311-313 MC BRIDE AVE', '309 MC BRIDE AVE', '307 MC BRIDE AVE',
#        '305 MC BRIDE AVE', '297-299 MC BRIDE AVE', '295 MC BRIDE AVE',
#        '293 MC BRIDE AVE', '289 MC BRIDE AVE', '287 MC BRIDE AVE',
#        '285 MC BRIDE AVE', '277-279 MC BRIDE AVE', '273-275 MC BRIDE AVE',
#        '269-271 MC BRIDE AVE', '265-267 MC BRIDE AVE',
#        '256-258 MC BRIDE AVE', '254-256 MC BRIDE AVE',
#        '250-252 MC BRIDE AVE', '273-277 CALDWELL AVE',
#        '446-448 MC BRIDE AVE', '450 MC BRIDE AVE', '454-456 MC BRIDE AVE',
#        '384 MC BRIDE AVE', '424 MC BRIDE AVE', '426-430 MC BRIDE AVE',
#        '436-438 MC BRIDE AVE', '286 MC BRIDE AVE', '280-284 MC BRIDE AVE',
#        '276-278 MC BRIDE AVE', '268 MC BRIDE AVE', '266 MC BRIDE AVE',
#        '361 MC BRIDE AVE', '357 MC BRIDE AVE', '397 MC BRIDE AVE',
#        '395 MC BRIDE AVE', '391 MC BRIDE AVE', '387-389 MC BRIDE AVE',
#        '385 MC BRIDE AVE', '383 MC BRIDE AVE', '403-409 MC BRIDE AVE',
#        '435 MC BRIDE AVE', '423-425 MC BRIDE AVE', '453 MC BRIDE AVE',
#        '445 MC BRIDE AVE', '465-467 MC BRIDE AVE', '1 BOULDER RUN',
#        '15 BOULDER RUN', '24 BOULDER RUN', '26 BOULDER RUN',
#        '28 BOULDER RUN', '29 BOULDER RUN', '30 BOULDER RUN',
#        '31 BOULDER RUN', '32 BOULDER RUN', '33 BOULDER RUN',
#        '34 BOULDER RUN', '35 BOULDER RUN', '36 BOULDER RUN',
#        '37 BOULDER RUN', '38 BOULDER RUN', '39 BOULDER RUN',
#        '41 BOULDER RUN', '42 BOULDER RUN', '43 BOULDER RUN',
#        '44 BOULDER RUN', '45 BOULDER RUN', '46 BOULDER RUN',
#        '47 BOULDER RUN', '48 BOULDER RUN', '49 BOULDER RUN',
#        '51 BOULDER RUN', '52 BOULDER RUN', '53 BOULDER RUN',
#        '55 BOULDER RUN', '56 BOULDER RUN', '57 BOULDER RUN',
#        '58 BOULDER RUN', '59 BOULDER RUN', '60 BOULDER RUN',
#        '61 BOULDER RUN', '62 BOULDER RUN', '64 BOULDER RUN',
#        '65 BOULDER RUN', '66 BOULDER RUN', '67 BOULDER RUN',
#        '68 BOULDER RUN', '69 BOULDER RUN', '73 BOULDER RUN',
#        '74 BOULDER RUN', '75 BOULDER RUN', '76 BOULDER RUN',
#        '77 BOULDER RUN', '78 BOULDER RUN', '79 BOULDER RUN',
#        '80 BOULDER RUN', '98-PT 100 WEBSTER AVE',
#        'PT 100-102 WEBSTER AVE', 'FRT 142 MILL ST', '79-PT 81 GARRET ST',
#        'PT 81-PT 83 GARRET ST', 'PT 83- PT 85 GARRET ST',
#        'PT 85-PT87 GARRET ST', 'PT 87-PT 91 GARRET ST',
#        'PT 305-307 CARLISLE AVE', 'PT 301-PT 303 CARLISLE AV',
#        'PT 299-301 CARLISLE AVE', '297-PT 299 CARLISLE AVE',
#        '180 ATLANTIC STREET #3', '273-277 PACIFIC ST', '7-8 LAMBERT TR',
#        '5-6 LAMBERT TR', '6040-606 MAIN STREET', '21-PT23 CHADWICK ST',
#        'PT23-PT-25 CHADWICK ST', '69-PT 71 COURT ST',
#        '1/2 135-137 ATLANTIC ST', '133-1/2 135 ATLANTIC ST',
#        '1247-1251 MADISON AVE', '20-1/2 22 PARK ST',
#        'R 337-339 STRAIGHT ST', 'PT445-447 SUMMER ST',
#        '443-PT445 SUMMER ST', '401-407 SUMMER ST UNIT 2',
#        '401-407SUMMER ST UNIT 3', '401-407 SUMMER ST UNIT4',
#        '401-407 SUMMER ST UNIT5', '401-407 SUMMER ST UNIT 6',
#        '401-407 SUMMER ST UNIT 7', '401-407 SUMMER ST UNIT 8',
#        '401-407 SUMMER ST UNIT 9', '401-407 SUMMER ST UNIT 11',
#        '401-407 SUMMER ST UNIT 12', '401-409 SUMMER ST UNIT 13',
#        '10 SEELEY ST', '12 SEELEY ST', '18 SEELEY ST', '20 SEELEY ST',
#        '22 SEELEY ST', '24 SEELEY ST', '26 SEELEY ST', '28 SEELEY ST',
#        '30 SEELEY ST', '13 SEELEY ST', '9-11 SEELEY ST', '462 GRAHAM AVE',
#        '464 GRAHAM AVE', '466 GRAHAM AVE', '468-470 GRAHAM AVE',
#        '472 GRAHAM AVE', '474 GRAHAM AVE', '476 GRAHAM AVE',
#        '478 GRAHAM AVE', 'PT33-35 MARTIN ST', '31-PT33 MARTIN ST',
#        '485-487 GRAHAM AVE', '483 GRAHAM AVE', '481 GRAHAM AVE',
#        '479 GRAHAM AVE', '477 GRAHAM AVE', '475 GRAHAM AVE',
#        '473 GRAHAM AVE', '469 GRAHAM AVE', '467 GRAHAM AVE',
#        '882-884 EAST 19TH ST REAR', '888-890 E 19TH ST',
#        '898-900 E 19TH ST', '229-233 LINDBERGH PL', '227 LINDBERGH PL',
#        '19-21SHEN ST', '22 GENESEE AVENUE', '34-36 GENESSE AVE',
#        '36 GOULD & 386 PAXTON', '510-516 GETTY AVE', '466-470 GETTY AVE',
#        '1069-1071 MAIN ST', 'R 386-388 GETTY AVE',
#        '242 PT 244 TRENTON AVE', '65-67 RAILWAY AVE',
#        '1090-1092 E 22ND ST', '1096-1098 E 22ND ST',
#        '1098-1100 E 22ND ST', '1092-1094 E 23RD ST',
#        '1096-1098 E 23RD ST', '1099-1101 E 22ND ST',
#        '1093-1097 E 22ND ST', '1078-1080 E 24TH ST',
#        '1090-1092 E 24TH ST', '1089-1091 E 24TH ST',
#        '1065-1067 E 25TH ST', '1022-1026 E 27TH ST',
#        '1051-1055 E 26TH ST', '997-999 E 28TH ST', '991-993 E 28TH ST',
#        '299-307 MARYLAND AVE', '289-291-293 DELAWARE AVE',
#        '272-294 LAKEVIEW AVE', '654-356 KNICKERBOCKER AVE',
#        '337-353 CROOKS AVE', '366-382 TRENTON AVE', '584-588 E 39TH ST',
#        '569-573 E 38TH ST', '578-582 E 38TH ST', '447-453 19TH AVE',
#        '387-393 19TH AVE', '466-470 E 38TH ST', '467-471 E 40TH ST',
#        'PT. 753- 755 20TH AVE', '751 PT. 753 20TH AVE.',
#        '745 PT 747 20TH AVE', '743 PT. 745 20TH AVE', '458-462 19TH AVE',
#        '292-294 E43RD ST(MCLEAN)', '677-683 PARK AVE', '673-677 PARK AVE',
#        '667-671 PARK AVE', '666-672 PARK AVE', '646-652 PARK AVE',
#        '491-525 BOULEVARD', '531-619 BOULEVARD', '855-887 BROADWAY',
#        '567-571 11TH AVE', '470-472 1OTH AVENUE', '467-471 12TH AVE',
#        '477-491 12TH AVE', '495-499 E 29TH ST', '785-791 14TH AVE',
#        '798-804 14TH AVE', '776-780 14TH AVE', '493-497 15TH AVE',
#        '690-692 14TH AVE', '666-672 14TH AVE', '584-588 E 29TH ST',
#        '613-617 E 28TH ST', '447-453 E 30TH ST', '338-354 E 35TH ST',
#        '495-499 E 33RD ST', '508-512 E 32ND ST', '588-592 20TH AVE',
#        '673-677 E 30TH ST', '201-207 22ND AVE FRONT',
#        '201-207 22ND AVE REAR', '967-969 MADISON AVE',
#        '962-964 E 22ND ST', '972-976 E 22ND ST', '962-964 E 23RD ST',
#        '983-985 E 22ND ST', '979-981 E 22ND ST', '967-969 E 22ND ST',
#        '992-994 E 24TH ST', '983-985 E 23RD ST', '981-983 E 23RD ST',
#        '967-969 E 23RD ST', '958-960 E 25TH ST', '888-890 E 28TH ST',
#        '896-900 E 28TH ST', '926-932 E 28TH ST', '958-960 E 28TH ST',
#        '962-964 E 28TH ST', '981-983 E 27TH ST', '975-979 E 27TH ST',
#        '969-973 E 27TH ST', '958-960 E 27TH ST', '989-993 E. 26TH ST.',
#        '981-983 EAST 26TH ST', '975-979 EAST 26TH ST',
#        'FT.976-978 EAST 26TH ST', '1018-PT 1022 E 24TH ST',
#        '1022-1026 E 23RD ST', '889-891 MADISON AVE',
#        '881-883 MADISON AVE', '871-873 MADISON AVE'], dtype=object)

# %%
df['gCode'] = df.propertyFullAddress.apply(geolocator.geocode)

# %%
df
# Out:
#           propertyLocation                       ownersName  \
# 0             98 HOPPER ST  VILLANUEVA,RAUL A & LUGO,JUSTIN
# 1             283 N 4TH ST              HENRIQUEZ, JENNY I.
# 2             281 N 4TH ST                     SILVA,OVIDIO
# 3             279 N 4TH ST        PLANE TREE PROPERTIES LLC
# 4             277 N 4TH ST        277 NORTH 4TH STREET, LLC
# ...                    ...                              ...
# 18920  911-913 MADISON AVE     HUERTAS, JOSE & LIDUVINA H/W
# 18921  909-911 MADISON AVE                   RAMOS, RUPERTO
# 18922      907 MADISON AVE               MOLINA,FRANCISCO J
# 18923  903-905 MADISON AVE          MIGUEL D. GARCIA CEPEDA
# 18924  901-903 MADISON AVE       MORAN, MANUEL & ASENET H/W
#
#             ownersMailingAddress          cityStateZip  units  \
# 0                   98 HOPPER ST    PATERSON NJ  07522      1
# 1             56 PATERSON AVENUE   PATERSON, NJ  07522      1
# 2                56 PATERSON AVE    PATERSON,NJ  07522      1
# 3                    PO BOX 1085     CLIFTON,NJ  07014      1
# 4      56 HAMBURG TURNPIKE # 253  RIVERDALE, NJ  07547      1
# ...                          ...                   ...    ...
# 18920            911 MADISON AVE    PATERSON NJ  07501      1
# 18921          258 AUTUMN STREET    PASSAIC, NJ  07055      1
# 18922            907 MADISON AVE    PATERSON NJ  07503      1
# 18923         905 MADISON AVENUE    PATERSON NJ  07501      1
# 18924            901 MADISON AVE    PATERSON NJ  07501      1
#
#                                         propertiesOwned  \
# 0                                        [98 HOPPER ST]
# 1                                        [283 N 4TH ST]
# 2      [281 N 4TH ST, 7 CIRCLE AVE, 54-56 PATERSON AVE]
# 3                                        [279 N 4TH ST]
# 4                                        [277 N 4TH ST]
# ...                                                 ...
# 18920                             [911-913 MADISON AVE]
# 18921                             [909-911 MADISON AVE]
# 18922                                 [907 MADISON AVE]
# 18923                             [903-905 MADISON AVE]
# 18924                             [901-903 MADISON AVE]
#
#        getNumberPropertiesOwned                propertyFullAddress  \
# 0                             1         98 HOPPER ST, PATERSON, NJ
# 1                             1         283 N 4TH ST, PATERSON, NJ
# 2                             3         281 N 4TH ST, PATERSON, NJ
# 3                             1         279 N 4TH ST, PATERSON, NJ
# 4                             1         277 N 4TH ST, PATERSON, NJ
# ...                         ...                                ...
# 18920                         1  911-913 MADISON AVE, PATERSON, NJ
# 18921                         1  909-911 MADISON AVE, PATERSON, NJ
# 18922                         1      907 MADISON AVE, PATERSON, NJ
# 18923                         1  903-905 MADISON AVE, PATERSON, NJ
# 18924                         1  901-903 MADISON AVE, PATERSON, NJ
#
#                                                    gCode
# 0      (98, Hopper Street, Prospect Park, Passaic Cou...
# 1      (283, North 4th Street, Paterson, Passaic Coun...
# 2      (281, North 4th Street, Paterson, Passaic Coun...
# 3      (279, North 4th Street, Paterson, Passaic Coun...
# 4      (277, North 4th Street, Paterson, Passaic Coun...
# ...                                                  ...
# 18920  (911, Madison Avenue, Paterson, Passaic County...
# 18921  (909, Madison Avenue, Paterson, Passaic County...
# 18922  (907, Madison Avenue, Paterson, Passaic County...
# 18923  (903, Madison Avenue, Paterson, Passaic County...
# 18924  (901, Madison Avenue, Paterson, Passaic County...
#
# [18925 rows x 9 columns]

# %%
df.to_pickle('paterson.pkl')

# %%
geocode_errors = [i for i,e in enumerate(df.gCode) if e == None]

# %%
df.iloc[geocode_errors]
# Out:
#              propertyLocation                           ownersName  \
# 171       PT 151 NORTH 1ST ST    GUICHARDO, ANGEL D. & FRANCISCO,L
# 172       PT 151 NORTH 1ST ST        PATERSON HABITAT FOR HUMANITY
# 176       PT 145 NORTH 1ST ST                         PUJOLS, LUIS
# 177       PT 145 NORTH 1ST ST                         HUNT, ANDREA
# 179       PT 141 NORTH 1ST ST      MUNOZ,PEDRO & MODESTA & EDUARDO
# ...                       ...                                  ...
# 18596  1018-PT 1022 E 24TH ST                   FIGUEROA, RANNEIRI
# 18629     1022-1026 E 23RD ST  MARTINEZ, JOSE & MARTINEZ, MRIA H/W
# 18779     889-891 MADISON AVE  VALENTIN, CLEOFE & WF & NELSON ETAL
# 18784     881-883 MADISON AVE               MARTINEZ,TEMISTOCLES D
# 18790     871-873 MADISON AVE     LA FAURIE, ADALBERTO & LIGIA H/W
#
#            ownersMailingAddress         cityStateZip  units  \
# 171    151 NORTH 1ST ST UNIT #2  PATERSON, NJ  07522      2
# 172        146 NORTH 1ST STREET  PATERSON, NJ  07522      2
# 176        145 NORTH 1ST STREET  PATERSON, NJ  07522      2
# 177      145-2 NORTH 1ST STREET  PATERSON, NJ  07522      2
# 179    141-143 NORTH 1ST STREET  PATERSON, NJ  07522      3
# ...                         ...                  ...    ...
# 18596     1020 EAST 24TH STREET  PATERSON, NJ  07513      1
# 18629            1024 E 23RD ST   PATERSON NJ  07513      1
# 18779           891 MADISON AVE   PATERSON NJ  07501      1
# 18784       881 883 MADISON AVE   PATERSON NJ  07501      1
# 18790           871 MADISON AVE   PATERSON NJ  07504      1
#
#                                          propertiesOwned  \
# 171                                [PT 151 NORTH 1ST ST]
# 172    [PT 151 NORTH 1ST ST, 5 GARFIELD AVE, 85 NORTH...
# 176                                [PT 145 NORTH 1ST ST]
# 177                                [PT 145 NORTH 1ST ST]
# 179                                [PT 141 NORTH 1ST ST]
# ...                                                  ...
# 18596                           [1018-PT 1022 E 24TH ST]
# 18629                              [1022-1026 E 23RD ST]
# 18779                              [889-891 MADISON AVE]
# 18784                              [881-883 MADISON AVE]
# 18790         [871-873 MADISON AVE, 869-871 MADISON AVE]
#
#        getNumberPropertiesOwned                   propertyFullAddress gCode
# 171                           1     PT 151 NORTH 1ST ST, PATERSON, NJ  None
# 172                           8     PT 151 NORTH 1ST ST, PATERSON, NJ  None
# 176                           1     PT 145 NORTH 1ST ST, PATERSON, NJ  None
# 177                           1     PT 145 NORTH 1ST ST, PATERSON, NJ  None
# 179                           1     PT 141 NORTH 1ST ST, PATERSON, NJ  None
# ...                         ...                                   ...   ...
# 18596                         1  1018-PT 1022 E 24TH ST, PATERSON, NJ  None
# 18629                         1     1022-1026 E 23RD ST, PATERSON, NJ  None
# 18779                         1     889-891 MADISON AVE, PATERSON, NJ  None
# 18784                         1     881-883 MADISON AVE, PATERSON, NJ  None
# 18790                         2     871-873 MADISON AVE, PATERSON, NJ  None
#
# [726 rows x 9 columns]

# %%
errors_df.propertyLocation.replace(paterson_repl_dict, value=None, inplace=True)

# %%
errors_df.propertyLocation = errors_df.propertyLocation.str.replace('PT ', '')

# %%
errors_df['propertyFullAddress'] = errors_df.propertyLocation + ", PATERSON, NJ"

# %%
errors_df.gCode = errors_df.propertyFullAddress.apply(geolocator.geocode)

# %%
geocode_errors = [i for i,e in enumerate(errors_df.gCode) if e == None]

# %%
errors_df.iloc[geocode_errors]
# Out:
#                propertyLocation                           ownersName  \
# 182            137 N 1ST ST 1/2                    HARRIS, SHIRLEY M
# 196    2 HABITAT WAY (N 2ND ST)                        GOMEZ,ALMA R.
# 197    1 HABITAT WAY (N 2ND ST)    PATERSON HABITAT FOR HUMANITY INC
# 198    4 HABITAT WAY (N 2ND ST)   PATERSON HABITAT FOR HUMANITY, INC
# 199    6 HABITAT WAY (N 2ND ST)         GARCIA,ROSA & VARGAS, RAFAEL
# ...                         ...                                  ...
# 18539   FT.976-978 EAST 26TH ST                     MANCILLA,GUSTAVO
# 18629       1022-1026 E 23RD ST  MARTINEZ, JOSE & MARTINEZ, MRIA H/W
# 18779       889-891 MADISON AVE  VALENTIN, CLEOFE & WF & NELSON ETAL
# 18784       881-883 MADISON AVE               MARTINEZ,TEMISTOCLES D
# 18790       871-873 MADISON AVE     LA FAURIE, ADALBERTO & LIGIA H/W
#
#       ownersMailingAddress              cityStateZip  units  \
# 182      117 NORTH 12TH ST  PROSPECT PARK, NJ  07508      1
# 196          2 REENSTRA CT        PATERSON NJ  07522      1
# 197            PO BOX 2585        PATERSON NJ  07509      1
# 198       146 N 1ST STREET        PATERSON NJ  07522      1
# 199       6 REENSTRA COURT        PATERSON NJ  07522      1
# ...                    ...                       ...    ...
# 18539    978 E.26TH STREET       PATERSON, NJ  07513      1
# 18629       1024 E 23RD ST        PATERSON NJ  07513      1
# 18779      891 MADISON AVE        PATERSON NJ  07501      1
# 18784  881 883 MADISON AVE        PATERSON NJ  07501      1
# 18790      871 MADISON AVE        PATERSON NJ  07504      1
#
#                                          propertiesOwned  \
# 182                                   [137 N 1ST ST 1/2]
# 196                           [2 HABITAT WAY (N 2ND ST)]
# 197    [1 HABITAT WAY (N 2ND ST), 179 N MAIN ST, 5 GA...
# 198    [4 HABITAT WAY (N 2ND ST), 78 CLINTON ST, PT 1...
# 199                           [6 HABITAT WAY (N 2ND ST)]
# ...                                                  ...
# 18539                          [FT.976-978 EAST 26TH ST]
# 18629                              [1022-1026 E 23RD ST]
# 18779                              [889-891 MADISON AVE]
# 18784                              [881-883 MADISON AVE]
# 18790         [871-873 MADISON AVE, 869-871 MADISON AVE]
#
#        getNumberPropertiesOwned                     propertyFullAddress gCode
# 182                           1          137 N 1ST ST 1/2, PATERSON, NJ  None
# 196                           1  2 HABITAT WAY (N 2ND ST), PATERSON, NJ  None
# 197                           7  1 HABITAT WAY (N 2ND ST), PATERSON, NJ  None
# 198                           3  4 HABITAT WAY (N 2ND ST), PATERSON, NJ  None
# 199                           1  6 HABITAT WAY (N 2ND ST), PATERSON, NJ  None
# ...                         ...                                     ...   ...
# 18539                         1   FT.976-978 EAST 26TH ST, PATERSON, NJ  None
# 18629                         1       1022-1026 E 23RD ST, PATERSON, NJ  None
# 18779                         1       889-891 MADISON AVE, PATERSON, NJ  None
# 18784                         1       881-883 MADISON AVE, PATERSON, NJ  None
# 18790                         2       871-873 MADISON AVE, PATERSON, NJ  None
#
# [666 rows x 9 columns]

# %%
df.append(errors_df.dropna(axis=0, subset=['gCode'])).to_pickle('paterson.pkl')

# %%
errors_df = errors_df.iloc[geocode_errors].copy()

# %%
# df.dropna(axis=0, subset=['gCode'], inplace=True)

# %%
df['Lat'] = [g.latitude for g in df.gCode]
df['Long'] = [g.longitude for g in df.gCode]

# %%
# df.to_pickle('paterson.pkl')

# %%
errors_df.to_pickle('errors_df.pkl')
